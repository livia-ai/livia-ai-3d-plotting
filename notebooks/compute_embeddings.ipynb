# %%
import pandas as pd

# Load metadata and construct data frame from gzipped sample file
metadata = pd.read_csv("sample-data/wm_1000_samples.csv.gz", compression="gzip")

# Pick only relevant columns
metadata = metadata[['id', 'title', 'districts', 'subjects', 'url', 'multimedia_default']]
metadata
# Out:
#           id                                              title  \
# 0    1902639  Handbeschriebener Zettel mit Angebot zur Nachb...
# 1    1902640  Zetteldokumentation zu den Corona-Balkonkonzer...
# 2    1902641  Zetteldokumentation zu den Corona-Balkonkonzer...
# 3    1902642  Zetteldokumentation zu den Corona-Balkonkonzer...
# 4    1902643  Zetteldokumentation zu den Corona-Balkonkonzer...
# ..       ...                                                ...
# 991   687726                               Elegantes Tageskleid
# 992   687915                                        Abendkleid
# 993   687916                        Dreiteiliges Sommerensemble
# 994   687995                                        Sommerkleid
# 995   697938                            Abendkleid mit Jäckchen
#
#                districts                                 subjects  \
# 0                    NaN      Handschrift, handgeschriebener Text
# 1    17. Bezirk: Hernals      Handschrift, handgeschriebener Text
# 2    17. Bezirk: Hernals      Handschrift, handgeschriebener Text
# 3                    NaN                                      NaN
# 4    17. Bezirk: Hernals      Handschrift, handgeschriebener Text
# ..                   ...                                      ...
# 991                  NaN  Kleid | Kleidung für offizielle Anlässe
# 992                  NaN  Kleid | Kleidung für offizielle Anlässe
# 993                  NaN                                    Kleid
# 994                  NaN                                    Kleid
# 995                  NaN  Kleid | Kleidung für offizielle Anlässe
#
#                                                 url  \
# 0    https://sammlung.wienmuseum.at/objekt/1902639/
# 1    https://sammlung.wienmuseum.at/objekt/1902640/
# 2    https://sammlung.wienmuseum.at/objekt/1902641/
# 3    https://sammlung.wienmuseum.at/objekt/1902642/
# 4    https://sammlung.wienmuseum.at/objekt/1902643/
# ..                                              ...
# 991   https://sammlung.wienmuseum.at/objekt/687726/
# 992   https://sammlung.wienmuseum.at/objekt/687915/
# 993   https://sammlung.wienmuseum.at/objekt/687916/
# 994   https://sammlung.wienmuseum.at/objekt/687995/
# 995   https://sammlung.wienmuseum.at/objekt/697938/
#
#                                     multimedia_default
# 0    https://sammlung.wienmuseum.at/openapi-images/...
# 1    https://sammlung.wienmuseum.at/openapi-images/...
# 2    https://sammlung.wienmuseum.at/openapi-images/...
# 3    https://sammlung.wienmuseum.at/openapi-images/...
# 4    https://sammlung.wienmuseum.at/openapi-images/...
# ..                                                 ...
# 991  https://sammlung.wienmuseum.at/openapi-images/...
# 992  https://sammlung.wienmuseum.at/openapi-images/...
# 993  https://sammlung.wienmuseum.at/openapi-images/...
# 994  https://sammlung.wienmuseum.at/openapi-images/...
# 995  https://sammlung.wienmuseum.at/openapi-images/...
#
# [996 rows x 6 columns]

# %%
import os
import sys

# Hack to import from 'livia' module
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from livia.embedding import Embedding

e = Embedding()
e.generate_embedding(metadata, ['title', 'districts', 'subjects'], 'id')

## Suggested API

# from livia.embedding import compute_embedding
# embeddings = compute_embedding(metadata, ['title', 'district', 'subject'])

## TODO e.g. zip embeddings array with ID, url, multimedia_default 
## Save embeddings
# embeddings.to_csv("sample-embeddings.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       7     sys.path.append(module_path)
#       9 from livia.embedding import Embedding
# ---> 11 e = Embedding()
#      12 e.generate_embedding(metadata, ['title', 'districts', 'subjects'], 'id')
#
# TypeError: __init__() missing 2 required positional arguments: 'embedding' and 'identifier'

# %%
## Suggested API
# embeddings.to_csv('sample-embeddings.csv')

# %%
# from livia.embedding import pca_reduce
# reduced_embeddings = pca_reduce(embeddings, n_components=3)

## TODO 3D scatterplot
